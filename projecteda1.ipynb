# %% [markdown]
# <a href="https://colab.research.google.com/github/aaryanphogaat/eda-project/blob/main/projecteda1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('cardata.csv')
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df['Selling_Price'].describe()
# Out:
# count    301.000000
# mean       4.661296
# std        5.082812
# min        0.100000
# 25%        0.900000
# 50%        3.600000
# 75%        6.000000
# max       35.000000
# Name: Selling_Price, dtype: float64

# %%
df['Present_Price'].value_counts()
# Out:
# Present_Price
# 9.40     15
# 13.60    13
# 5.70      8
# 1.47      7
# 4.43      7
#          ..
# 6.10      1
# 13.09     1
# 11.60     1
# 11.00     1
# 12.50     1
# Name: count, Length: 147, dtype: int64

# %%
df['Selling_Price'][:5]
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
df[['Selling_Price', 'Present_Price', 'Kms_Driven']]
# Out:
#      Selling_Price  Present_Price  Kms_Driven
# 0             3.35           5.59       27000
# 1             4.75           9.54       43000
# 2             7.25           9.85        6900
# 3             2.85           4.15        5200
# 4             4.60           6.87       42450
# ..             ...            ...         ...
# 296           9.50          11.60       33988
# 297           4.00           5.90       60000
# 298           3.35          11.00       87934
# 299          11.50          12.50        9000
# 300           5.30           5.90        5464
#
# [301 rows x 3 columns]

# %%
df[df['Present_Price'] > 5] #cars which are more than 5 lakh present price .
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0             ritz  2014           3.35           5.59       27000    Petrol
# 1              sx4  2013           4.75           9.54       43000    Diesel
# 2             ciaz  2017           7.25           9.85        6900    Petrol
# 4            swift  2014           4.60           6.87       42450    Diesel
# 5    vitara brezza  2018           9.25           9.83        2071    Diesel
# ..             ...   ...            ...            ...         ...       ...
# 296           city  2016           9.50          11.60       33988    Diesel
# 297           brio  2015           4.00           5.90       60000    Petrol
# 298           city  2009           3.35          11.00       87934    Petrol
# 299           city  2017          11.50          12.50        9000    Diesel
# 300           brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# ...

# %%
df[(df['Present_Price'] == 7) & (df['Selling_Price'] >= 4)]
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 264    amaze  2015            4.0            7.0       40026    Petrol
#
#     Seller_Type Transmission  Owner
# 264      Dealer       Manual      0

# %%
df.iloc[0:5]
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.loc[0:5, ['Selling_Price', 'Present_Price']]
# Out:
#    Selling_Price  Present_Price
# 0           3.35           5.59
# 1           4.75           9.54
# 2           7.25           9.85
# 3           2.85           4.15
# 4           4.60           6.87
# 5           9.25           9.83

# %%
df.sort_values('Present_Price', ascending=False).head()
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 86  land cruiser  2010          35.00          92.60       78000    Diesel
# 64      fortuner  2017          33.00          36.23        6000    Diesel
# 63      fortuner  2015          23.50          35.96       47000    Diesel
# 62      fortuner  2014          18.75          35.96       78000    Diesel
# 59      fortuner  2014          19.99          35.96       41000    Diesel
#
#    Seller_Type Transmission  Owner
# 86      Dealer       Manual      0
# 64      Dealer    Automatic      0
# 63      Dealer    Automatic      0
# 62      Dealer    Automatic      0
# 59      Dealer    Automatic      0

# %%
df.groupby('Selling_Price')['Present_Price'].mean()
# Out:
# Selling_Price
# 0.10      0.75
# 0.12      0.58
# 0.15      0.57
# 0.16      0.51
# 0.17      0.52
#          ...
# 20.75    25.39
# 23.00    28.87
# 23.50    35.96
# 33.00    36.23
# 35.00    92.60
# Name: Present_Price, Length: 156, dtype: float64

# %%
df.groupby('Kms_Driven')['Present_Price'].agg(['mean', 'max', 'count'])
# Out:
#               mean    max  count
# Kms_Driven
# 500          0.745   0.95      2
# 1000         0.550   0.55      1
# 1200         1.600   1.60      1
# 1300         0.730   0.95      2
# 1400         1.820   1.82      1
# ...            ...    ...    ...
# 135154      12.350  12.35      1
# 142000      23.730  23.73      1
# 197176      13.460  13.46      1
# 213000       1.050   1.05      1
# 500000       0.520   0.52      1
#
# [206 rows x 3 columns]

# %%
#creating new coloums
df['brandnew_price'] = df['Selling_Price']
df[['Selling_Price', 'brandnew_price']].head()
# Out:
#    Selling_Price  brandnew_price
# 0           3.35            3.35
# 1           4.75            4.75
# 2           7.25            7.25
# 3           2.85            2.85
# 4           4.60            4.60

# %%
df.groupby('Year')['Selling_Price'].mean()
# Out:
# Year
# 2003    1.300000
# 2004    1.500000
# 2005    2.487500
# 2006    1.437500
# 2007    0.160000
# 2008    1.002857
# 2009    2.816667
# 2010    5.262667
# 2011    2.375263
# 2012    3.841304
# 2013    3.540909
# 2014    4.762105
# 2015    5.927049
# 2016    5.213200
# 2017    6.209143
# 2018    9.250000
# Name: Selling_Price, dtype: float64

# %%
df.isnull().sum()
# Out:
# Car_Name          0
# Year              0
# Selling_Price     0
# Present_Price     0
# Kms_Driven        0
# Fuel_Type         0
# Seller_Type       0
# Transmission      0
# Owner             0
# brandnew_price    0
# dtype: int64

# %%
df.query('Kms_Driven > 4 and Present_Price  < 500000')
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  brandnew_price
# 0        Dealer       Manual      0            3.35
# ...

# %%
df.corr(numeric_only=True)['Selling_Price'].sort_values(ascending=False)
# Out:
# Selling_Price     1.000000
# brandnew_price    1.000000
# Present_Price     0.878983
# Year              0.236141
# Kms_Driven        0.029187
# Owner            -0.088344
# Name: Selling_Price, dtype: float64

# %%
import matplotlib.pyplot as plt
df['Present_Price'].hist(bins=50, figsize=(10,5))
plt.title('Selling_Price')
plt.xlabel('Present_Price')
# Out:
# Text(0.5, 0, 'Present_Price')

# %%
df.plot(kind='scatter', x='Kms_Driven', y='Selling_Price', alpha=0.3)
# Out:
# <Axes: xlabel='Kms_Driven', ylabel='Selling_Price'>

# %%
df[['Selling_Price', 'Present_Price']].boxplot(by='Selling_Price', figsize=(10,6))
# Out:
# <Axes: title={'center': 'Present_Price'}, xlabel='[Selling_Price]'>

# %%
df_dropped = df.drop(['Year', 'Owner'], axis=1)
df_dropped.head()
# Out:
#   Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0     ritz           3.35           5.59       27000    Petrol      Dealer
# 1      sx4           4.75           9.54       43000    Diesel      Dealer
# 2     ciaz           7.25           9.85        6900    Petrol      Dealer
# 3  wagon r           2.85           4.15        5200    Petrol      Dealer
# 4    swift           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  brandnew_price
# 0       Manual            3.35
# 1       Manual            4.75
# 2       Manual            7.25
# 3       Manual            2.85
# 4       Manual            4.60

# %%
df.to_csv('processed_cardata.csv.csv', index=False)
